# %%
import numpy as np
import matplotlib.pyplot as plt
from system import System
from algo import Algo
from tools import repeat_exp,repeat_exp_debug, plot_with_trajectory_confidence_interval

# %%
import img2pdf

# %% [markdown]
# # Main algorithm

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB1,hist_OtO1,hist_LCB1=repeat_exp(K,m,T,means,10,"main",alpha=0.2)
# Out:
#   0%|                                                   | 0/200 [00:00<?, ?it/s]/Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:18: RuntimeWarning: invalid value encountered in divide
#   self.upper_bound = system.sum_rewards/system.sample_count
# /Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:23: RuntimeWarning: divide by zero encountered in divide
#   self.upper_bound+=np.sqrt(np.log(system.K/self.delta)/system.sample_count)
# /Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:26: RuntimeWarning: invalid value encountered in divide
#   lower_bound = system.sum_rewards/system.sample_count
# /Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:30: RuntimeWarning: divide by zero encountered in divide
#   lower_bound-=np.sqrt(np.log(system.K/self.delta)/system.sample_count)
# ...

# %%
plot_with_trajectory_confidence_interval(hist_OtO1,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB1, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB1, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT sampled in offline data")
plt.legend()
# Save the plot as a PDF
plt.savefig('plots/Largehorizonoptsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB2,hist_OtO2,hist_LCB2=repeat_exp(K,m,T,means,10,"main",alpha=0.2)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:02<00:00, 72.63it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO2,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB2, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB2, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT not sampled in offline data")
plt.legend()
# Save the plot as a PDF
plt.savefig('plots/Largehorizonoptnotsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB3,hist_OtO3,hist_LCB3=repeat_exp(K,m,T,means,10,"main",alpha=0.2)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 668.14it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO3,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB3, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB3, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=200, m=2000, OPT sampled in offline data")
plt.legend()
# Save the plot as a PDF
plt.savefig('plots/smallhorizonoptsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB4,hist_OtO4,hist_LCB4=repeat_exp(K,m,T,means,10,"main",alpha=0.2)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 536.98it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO4,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB4, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB4, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=200, m=2000, OPT not sampled in offline data")
plt.legend()
# Save the plot as a PDF
plt.savefig('plots/smallhorizonoptnotsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %% [markdown]
# # Unknown Horizon

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB5,hist_OtO5,hist_LCB5=repeat_exp(K,m,T,means,10,"unknown horizon",0.005,alpha=0.6)
# Out:
#   0%|                                                   | 0/200 [00:00<?, ?it/s]/Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:20: RuntimeWarning: divide by zero encountered in divide
#   self.upper_bound+=np.sqrt(np.log(system.K*(t+1)**2/self.delta)/system.sample_count)
# /Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:28: RuntimeWarning: divide by zero encountered in divide
#   lower_bound-=np.sqrt(np.log(system.K*(t+1)**2/self.delta)/system.sample_count)
# /Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:20: RuntimeWarning: divide by zero encountered in divide
#   self.upper_bound+=np.sqrt(np.log(system.K*(t+1)**2/self.delta)/system.sample_count)
# /Users/sentenac/Desktop/offline learning/exp with unknown horizon/algo.py:28: RuntimeWarning: divide by zero encountered in divide
#   lower_bound-=np.sqrt(np.log(system.K*(t+1)**2/self.delta)/system.sample_count)
# ...

# %%
plot_with_trajectory_confidence_interval(hist_OtO5,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB5, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB5, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT sampled in offline data")
plt.legend()
plt.savefig('plots/Tunknownlargehorizonoptsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB6,hist_OtO6,hist_LCB6=repeat_exp(K,m,T,means,10,"unknown horizon",0.005,alpha=0.6)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:02<00:00, 70.28it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO6,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB6, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB6, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/Tunknownlargehorizonoptnotsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB7,hist_OtO7,hist_LCB7=repeat_exp(K,m,T,means,10,"unknown horizon",0.005,alpha=0.6)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 812.81it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO7,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB7, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB7, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=200,m=2000, OPT sampled in offline data")
plt.legend()
plt.savefig('plots/Tunknownsmallhorizonoptsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB8,hist_OtO8,hist_LCB8=repeat_exp(K,m,T,means,10,"unknown horizon",0.005,alpha=0.6)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 863.89it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO8,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB8, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB8, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=200,m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/Tunknownsmallhorizonoptnotsampled.pdf', format='pdf')

# Show the plot
plt.show()

# %% [markdown]
# # Partial update of parameters

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB9,hist_OtO9,hist_LCB9=repeat_exp(K,m,T,means,10,"partial update param",alpha =0.2)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:02<00:00, 75.00it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO9,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB9, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB9, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)

#plt.title("T=m=2000, OPT sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/partialupdateparamTlargeoptsampled.pdf', format='pdf')

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB10,hist_OtO10,hist_LCB10=repeat_exp(K,m,T,means,10,"partial update param",alpha=0.2)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:02<00:00, 67.93it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO10,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB10, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB10, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/partialupdateparamTlargeoptnotsampled.pdf', format='pdf')

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB11,hist_OtO11,hist_LCB11=repeat_exp(K,m,T,means,10,"partial update param",alpha=0.2)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 807.80it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO11,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB11, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB11, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=200,m=2000, OPT sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/partialupdateparamTsmalloptsampled.pdf', format='pdf')

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB12,hist_OtO12,hist_LCB12=repeat_exp(K,m,T,means,10,"partial update param", alpha=0.2)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 909.93it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO12,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB12, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB12, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=200,m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/partialupdateparamTsmalloptnotsampled.pdf', format='pdf')

# %% [markdown]
# # Full param update

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB13,hist_OtO13,hist_LCB13=repeat_exp(K,m,T,means,10,"full update param",alpha=0.2)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:02<00:00, 68.88it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO13,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB13, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB13, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/fullupdateparamTlargeoptsampled.pdf', format='pdf')

# %%
K=20
m=2000
T=2000
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB14,hist_OtO14,hist_LCB14=repeat_exp(K,m,T,means,10,"full update param",alpha=0.2)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:02<00:00, 68.57it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO14,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB14, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB14, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/fullupdateparamTlargeoptnotsampled.pdf', format='pdf')

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB15,hist_OtO15,hist_LCB15=repeat_exp(K,m,T,means,10,"full update param",alpha=0.2)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 845.20it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO15,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB15, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB15, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/fullupdateparamTsmalloptsampled.pdf', format='pdf')

# %%
K=20
m=2000
T=200
means=[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.25,0.25,0.25,0.75,0.25,0.25,0.25,0.25,0.25,0.25]
hist_UCB16,hist_OtO16,hist_LCB16=repeat_exp(K,m,T,means,10,"full update param", alpha=0.2)
# Out:
# 100%|████████████████████████████████████████| 200/200 [00:00<00:00, 833.47it/s]

# %%
plot_with_trajectory_confidence_interval(hist_OtO16,color="red", label="OtO")
plot_with_trajectory_confidence_interval(hist_UCB16, label="UCB",color="blue")
plot_with_trajectory_confidence_interval(hist_LCB16, label="LCB",color="orange")
plt.xlabel("iteration",fontsize=16)
plt.ylabel("Regret",fontsize=16)
#plt.title("T=m=2000, OPT not sampled in offline data")
plt.legend()
plt.savefig('plots/appendix/fullupdateparamTsmalloptnotsampled.pdf', format='pdf')
